# %% [markdown]
# # Thử nghiệm 2.1: ViSoBERT + ConvNeXt + Huber Loss

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt

# %%
# !python main.py --loss_fn huber --mode train_text --epochs 15 --batch_size 16 --grad_accum_steps 1 --text_model_name uitnlp/visobert --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image

# %%
# !python main.py --loss_fn huber --mode train_image --epochs 15 --batch_size 8 --grad_accum_steps 2 --image_model_name efficientnet_b3 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image

# %%
# !python main.py --loss_fn huber --mode train_fusion --epochs 10 --batch_size 8 --grad_accum_steps 2 --unfreeze_text_layers 1 --unfreeze_image_layers 1 --max_length 256 --text_model_name uitnlp/visobert --image_model_name efficientnet_b3 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image

# %%
# !python test.py --mode train_fusion --text_model_name uitnlp/visobert --image_model_name efficientnet_b3 --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image
