# %% [markdown]
# # Thử nghiệm 1.1: ViDeBERTa-base + Swin-B
# Thử nghiệm này sử dụng mô hình tối ưu tiếng Việt cho nhánh Text và mô hình Swin Transformer phân cấp cho nhánh Image.

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt

# %%
# !python main.py --mode train_text --epochs 5 --lr 1e-5 --text_model_name FPTAI/vibert-base-cased --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image

# %%
# !python main.py --mode train_image --epochs 10 --lr 1e-5 --weight_decay 0.05 --image_model_name swin_base_patch4_window7_224 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image

# %%
# !python main.py --mode train_fusion --epochs 15 --lr 1e-4 --text_model_name FPTAI/vibert-base-cased --image_model_name swin_base_patch4_window7_224 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image

# %%
# !python test.py --mode train_fusion --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image
