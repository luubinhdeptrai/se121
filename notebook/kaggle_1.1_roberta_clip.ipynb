# %% [markdown]
# # Thử nghiệm 1.1: RoBERTa + CLIP

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 13150, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 13150 (delta 8), reused 14 (delta 5), pack-reused 13129 (from 1)
# Receiving objects: 100% (13150/13150), 873.04 MiB | 50.01 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# /kaggle/working/SE365
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 74.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# ...

# %%
# !python main.py --mode train_text --epochs 15 --batch_size 16 --grad_accum_steps 1 --text_model_name FacebookAI/roberta-base --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image
# Out:
# ====== MODE: TRAIN_TEXT ======
# Using device: cuda
# ...
# config.json: 100%|█████████████████████████████| 481/481 [00:00<00:00, 1.99MB/s]
# tokenizer_config.json: 100%|██████████████████| 25.0/25.0 [00:00<00:00, 102kB/s]
# vocab.json: 899kB [00:00, 26.6MB/s]
# merges.txt: 456kB [00:00, 92.7MB/s]
# tokenizer.json: 1.36MB [00:00, 103MB/s]
# preprocessor_config.json: 100%|████████████████| 266/266 [00:00<00:00, 1.52MB/s]
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Dataset...
# Đã nạp 4800 mẫu cho Train và 600 mẫu cho Val
# Initializing Model...
# model.safetensors: 100%|██████████████████████| 499M/499M [00:02<00:00, 205MB/s]
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1396.47it/s, Materializing param=
# ...

# %%
# !python main.py --mode train_image --epochs 15 --batch_size 8 --grad_accum_steps 2 --image_model_name vit_base_patch32_clip_224.openai --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image
# Out:
# ====== MODE: TRAIN_IMAGE ======
# Using device: cuda
# ...
# config.json: 100%|█████████████████████████████| 615/615 [00:00<00:00, 2.96MB/s]
# tokenizer_config.json: 100%|██████████████████| 25.0/25.0 [00:00<00:00, 171kB/s]
# sentencepiece.bpe.model: 100%|█████████████| 5.07M/5.07M [00:00<00:00, 45.7MB/s]
# tokenizer.json: 9.10MB [00:00, 42.2MB/s]
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Dataset...
# Đã nạp 4800 mẫu cho Train và 600 mẫu cho Val
# Initializing Model...
# pytorch_model.bin: 100%|██████████████████████| 605M/605M [00:04<00:00, 143MB/s]
# Epoch 1/15: 100%|██████| 600/600 [06:51<00:00,  1.46it/s, loss=13.9, lr=6.67e-6]
#
# Epoch 1/15 | Train Loss: 27.4618 | Val Loss: 12.2742
# ...

# %%
# !python main.py --mode train_fusion --epochs 10 --batch_size 8 --grad_accum_steps 2 --unfreeze_text_layers 1 --unfreeze_image_layers 1 --max_length 256 --text_model_name FacebookAI/roberta-base --image_model_name vit_base_patch32_clip_224.openai --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image
# Out:
# ====== MODE: TRAIN_FUSION ======
# Using device: cuda
# ...
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Dataset...
# Đã nạp 4800 mẫu cho Train và 600 mẫu cho Val
# Initializing Model...
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1475.74it/s, Materializing param=
# RobertaModel LOAD REPORT from: FacebookAI/roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# ...

# %%
# !python test.py --mode train_fusion --text_model_name FacebookAI/roberta-base --image_model_name vit_base_patch32_clip_224.openai --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image
# Out:
# ====== TESTING MODE: TRAIN_FUSION ======
# ...
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Test Dataset...
# Đã nạp 600 mẫu Test
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1341.78it/s, Materializing param=
# RobertaModel LOAD REPORT from: FacebookAI/roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# ...
